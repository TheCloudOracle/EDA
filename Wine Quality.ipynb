# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/wine quality/winequality-red.csv', sep=';')
data['quality'] = data['quality'] - 2
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        3
# 1      9.8        3
# 2      9.8        3
# ...

# %%
data.isnull().values.sum()
# Out:
# np.int64(0)

# %%
data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
for col in data.columns:
    print(f'{col}\nUnique Values: {data[col].nunique()}\n')
# Out:
# fixed acidity
# Unique Values: 96
#
# volatile acidity
# Unique Values: 143
#
# citric acid
# Unique Values: 80
#
# residual sugar
# Unique Values: 91
#
# chlorides
# Unique Values: 153
#
# free sulfur dioxide
# Unique Values: 60
#
# total sulfur dioxide
# Unique Values: 144
#
# density
# Unique Values: 436
#
# pH
# Unique Values: 89
#
# sulphates
# Unique Values: 96
#
# alcohol
# Unique Values: 65
#
# quality
# Unique Values: 6

# %%
data.shape[0]
# Out:
# 1599

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.barplot(data=data, x='quality', y='alcohol')
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
sns.barplot(data=data, x='quality', y='sulphates')
# Out:
# <Axes: xlabel='quality', ylabel='sulphates'>

# %%
sns.barplot(data=data, x='quality', y='citric acid')
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
sns.histplot(data=data, x='alcohol', kde=True)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
# Out:
# <Axes: xlabel='quality', ylabel='quality'>

# %%
sns.kdeplot(data=data, x='sulphates', fill=True)
# Out:
# <Axes: xlabel='sulphates', ylabel='Density'>

# %%
sns.lineplot(data=data, y='sulphates', x='alcohol')
# Out:
# <Axes: xlabel='alcohol', ylabel='sulphates'>

# %%
sns.scatterplot(data=data, x='alcohol', y='quality')
# Out:
# <Axes: xlabel='alcohol', ylabel='quality'>

# %%
sns.histplot(data=data, x='alcohol', hue='quality', kde=True)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>
